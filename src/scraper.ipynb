# %%
import pandas as pd
import os
os.getcwd()
# Out:
# 'c:\\Users\\nishi\\OneDrive - University of St Andrews\\Lecture Notes\\Diss\\src'

# %%
# path to excel file
esg_doc = "..\docs\Refinitiv ESG docs\esg_data_guide.xlsx"

xl = pd.read_excel(esg_doc, sheet_name="Field Description")
xl.head()
# Out:
#        Pillar  Order Category           RDP API Field Name  \
# 0  ESG Scores    0.0      NaN                TR.TRESGScore
# 1  ESG Scores    0.0      NaN               TR.TRESGCScore
# 2  ESG Scores    0.0      NaN  TR.TRESGCControversiesScore
# 3  ESG Scores    NaN      NaN    TR.EnvironmentPillarScore
# 4  ESG Scores    NaN      NaN     TR.GovernancePillarScore
#
#       RDP Bulk Field Name                     Title  \
# 0                ESGScore                 ESG Score
# 1        ESGCombinedScore        ESG Combined Score
# 2  ESGCControversiesScore   ESG Controversies Score
# 3  EnvironmentPillarScore  Environment Pillar Score
# 4   GovernancePillarScore   Governance Pillar Score
#
#                                      Description (d) Data type (dt)   Units  \
# 0  Refinitiv's ESG Score is an overall company sc...          Float  Number
# 1  Refinitiv's ESG Combined Score is an overall c...          Float  Number
# ...

# %%
col_str = xl['RDP API Field Name'].to_string().split()

field_names = [i for i in col_str if 'TR' in i]
str(field_names)
# Out:
# ['TR.TRESGScore',
#  'TR.TRESGCScore',
#  'TR.TRESGCControversiesScore',
#  'TR.EnvironmentPillarScore',
#  'TR.GovernancePillarScore',
#  'TR.SocialPillarScore',
#  'TR.TRESGResourceUseScore',
#  'TR.TRESGEmissionsScore',
#  'TR.TRESGInnovationScore',
#  'TR.TRESGWorkforceScore',
#  'TR.TRESGHumanRightsScore',
#  'TR.TRESGCommunityScore',
#  'TR.TRESGProductResponsibilityScore',
#  'TR.TRESGManagementScore',
#  'TR.TRESGShareholdersScore',
#  'TR.TRESGCSRStrategyScore',
#  'TR.AnalyticCO2',
#  'TR.AnalyticVOCorPMReduction',
#  'TR.AnalyticTotalWaste',
#  'TR.AnalyticWasteRecyclingRatio',
#  'TR.AnalyticHazardousWaste',
#  'TR.AnalyticDischargeWaterSystem',
#  'TR.AnalyticEnvExpenditures',
#  'TR.PolicyEmissions',
#  'TR.TargetsEmissions',
#  'TR.BiodiversityImpactReduction',
#  'TR.CO2EmissionTotal',
#  'TR.CO2DirectScope1',
#  'TR.CO2IndirectScope2',
#  'TR.FlaringGases',
#  'TR.CementCO2Emission',
#  'TR.OzoneDepletingSubstances',
#  'TR.NOxSOxEmissionsReduction',
# ...
